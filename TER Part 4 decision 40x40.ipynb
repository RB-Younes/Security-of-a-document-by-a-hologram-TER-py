# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from google.colab.patches import cv2_imshow
import tensorflow as tf
patch_size = (40,40)

# %% [markdown]
# *    **Prediction**

# %%
def divide_image_into_patches(image_path, patch_size):
    image =  cv2.imread(image_path)
    height, width = image.shape[:2]
    patch_height, patch_width = patch_size
    patches = []
    cpt = 0
    for y in range(0, height, patch_height):
        for x in range(0, width, patch_width):
            patch = image[y:y+patch_height, x:x+patch_width]
            patches.append(patch)
            cpt+=1
    return patches,cpt

# %%
def get_patches_mask(patches_mask):
  cpt_R = 0
  cpt_G = 0
  for i,patch in enumerate(patches_mask):
    first_pixel = patch[0, 0]
    if (first_pixel == [0, 255, 0]).all():
     cpt_G += 1
    elif (first_pixel == [0, 0, 255]).all():
     cpt_R += 1
  return cpt_R , cpt_G

# %%
def calculate_ratios(cpt_R, cpt_G):
    return cpt_R / 150, cpt_G / 150

# %%
dossier_H = "/content/drive/MyDrive/TER Data/final best color maps 40x40/Holo"
dossier_NH = "/content/drive/MyDrive/TER Data/final best color maps 40x40/No-Holo"

# %%
min_G_ratio = 1 - 0.8259471102223632
prediction = []
actual_calss = []
tot_G = 0
for path in [dossier_H,dossier_NH]:
  for item in os.listdir(path):
          if os.path.isfile(os.path.join(path, item)) :
              patches,cpt = divide_image_into_patches(str(os.path.join(path, item)), patch_size)
              cpt_R , cpt_G = get_patches_mask(patches)
              tot_G = tot_G + cpt_G
              if path ==  dossier_H :
                G_ratio = cpt_G/150
                print("class = Holo with RED_ratio = {} and GREEN_ratio = {}".format(cpt_R/150 ,cpt_G/150))
                actual_calss.append("Holo")
                if G_ratio >= min_G_ratio :
                    prediction.append("Holo")
                else:
                    prediction.append("No-Holo")
              else:
                G_ratio = cpt_G/150
                print("class = No-Holo with RED_ratio = {} and GREEN_ratio = {}".format(cpt_R/150 ,cpt_G/150))
                actual_calss.append("No-Holo")
                if G_ratio >= min_G_ratio :
                    prediction.append("Holo")
                else:
                    prediction.append("No-Holo")
# Out:
# class = Holo with RED_ratio = 0.5866666666666667 and GREEN_ratio = 0.41333333333333333
# class = Holo with RED_ratio = 0.6933333333333334 and GREEN_ratio = 0.30666666666666664
# class = Holo with RED_ratio = 0.6 and GREEN_ratio = 0.4
# class = Holo with RED_ratio = 0.6733333333333333 and GREEN_ratio = 0.32666666666666666
# class = Holo with RED_ratio = 0.5333333333333333 and GREEN_ratio = 0.4666666666666667
# class = Holo with RED_ratio = 0.5733333333333334 and GREEN_ratio = 0.4266666666666667
# class = Holo with RED_ratio = 0.7333333333333333 and GREEN_ratio = 0.26666666666666666
# class = Holo with RED_ratio = 0.6133333333333333 and GREEN_ratio = 0.38666666666666666
# class = Holo with RED_ratio = 0.7266666666666667 and GREEN_ratio = 0.2733333333333333
# class = Holo with RED_ratio = 0.8333333333333334 and GREEN_ratio = 0.16666666666666666
# class = Holo with RED_ratio = 0.5733333333333334 and GREEN_ratio = 0.4266666666666667
# class = Holo with RED_ratio = 0.52 and GREEN_ratio = 0.48
# class = Holo with RED_ratio = 0.5733333333333334 and GREEN_ratio = 0.4266666666666667
# class = Holo with RED_ratio = 0.7666666666666667 and GREEN_ratio = 0.23333333333333334
# class = Holo with RED_ratio = 0.5866666666666667 and GREEN_ratio = 0.41333333333333333
# class = No-Holo with RED_ratio = 0.9733333333333334 and GREEN_ratio = 0.02666666666666667
# class = No-Holo with RED_ratio = 0.9933333333333333 and GREEN_ratio = 0.006666666666666667
# class = No-Holo with RED_ratio = 0.9933333333333333 and GREEN_ratio = 0.006666666666666667
# class = No-Holo with RED_ratio = 0.9866666666666667 and GREEN_ratio = 0.013333333333333334
# class = No-Holo with RED_ratio = 0.96 and GREEN_ratio = 0.04
# class = No-Holo with RED_ratio = 0.98 and GREEN_ratio = 0.02
# class = No-Holo with RED_ratio = 0.9533333333333334 and GREEN_ratio = 0.04666666666666667
# class = No-Holo with RED_ratio = 0.9666666666666667 and GREEN_ratio = 0.03333333333333333
# class = No-Holo with RED_ratio = 0.9866666666666667 and GREEN_ratio = 0.013333333333333334
# class = No-Holo with RED_ratio = 0.94 and GREEN_ratio = 0.06
# class = No-Holo with RED_ratio = 0.9666666666666667 and GREEN_ratio = 0.03333333333333333
# class = No-Holo with RED_ratio = 0.8333333333333334 and GREEN_ratio = 0.16666666666666666
# class = No-Holo with RED_ratio = 0.9866666666666667 and GREEN_ratio = 0.013333333333333334
# class = No-Holo with RED_ratio = 1.0 and GREEN_ratio = 0.0
# class = No-Holo with RED_ratio = 0.9733333333333334 and GREEN_ratio = 0.02666666666666667

# %%
# Initialize variables to count correct predictions
correct_predictions = 0

# Iterate through both lists simultaneously
for pred, actual in zip(prediction, actual_calss):
    if pred == actual:
        correct_predictions += 1

# Calculate accuracy
accuracy = correct_predictions / len(prediction) * 100

print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 96.66666666666667 %

# %%
print(tot_G)
# Out:
# 888
